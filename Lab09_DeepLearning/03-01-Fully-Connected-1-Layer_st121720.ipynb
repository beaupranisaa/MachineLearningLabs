# %%
import numpy as np
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
y = np.matrix(data.target).T
X = np.matrix(data.data)
M = X.shape[0]
N = X.shape[1]

# Normalize each input feature

def normalize(X):
    M = X.shape[0]
    XX = X - np.tile(np.mean(X,0),[M,1])
    XX = np.divide(XX, np.tile(np.std(XX,0),[M,1]))
    return XX

XX = normalize(X)

h2 = 5
h1 = 6
W = [[], np.random.normal(0,0.1,[N,h1]),
         np.random.normal(0,0.1,[h1,1])]
b = [[], np.random.normal(0,0.1,[h1,1]),
         np.random.normal(0,0.1,[1,1])]
L = len(W)-1
def act(z):
    return 1/(1+np.exp(-z))

def relu(z):
    return np.maximum(0, z)

def reludev(z):
    prod = relu(z)
    return np.maximum(sign(prod), 0)

def actder(z):
    az = act(z)
    prod = np.multiply(az,1-az)
    return prod

def ff(x,W,b):
    L = len(W)-1
    a = x
    for l in range(1,L+1):
        z = W[l].T*a+b[l]
        a = relu(z)
    return a

def loss(y,yhat):
    return -((1-y) * np.log(1-yhat) + y * np.log(yhat))
def lossmse(y,yhat):
    return np.square(np.subtract(y,yhat)).mean()
# Use mini-batch size 1

alpha = 0.01
max_iter = 10
for iter in range(0, max_iter):
    loss_this_iter = 0
    order = np.random.permutation(M)
    for i in range(0,M):
        
        # Grab the pattern order[i]
        
        x_this = XX[order[i],:].T
        y_this = y[order[i],0]

        # Feed forward step
        
        a = [x_this]
        z = [[]]
        delta = [[]]
        dW = [[]]
        db = [[]]
        for l in range(1,L+1):
            z.append(W[l].T*a[l-1]+b[l])
            a.append(relu(z[l]))
            # Just to give arrays the right shape for the backprop step
            delta.append([]); dW.append([]); db.append([])
        loss_this_pattern = lossmse(y_this,a[L][0,0])
        #print(loss_this_pattern)
        loss_this_iter = loss_this_iter + loss_this_pattern
            
        # Backprop step... (to fill in!)
        delta[L] = a[L] - y_this
        db[L] = delta[L].copy()
        dW[L] = a[L-1] * delta[L]
                
        # Check delta calculation
        
        if False:
            print('Target: %f' % y_this)
            print('y_hat: %f' % a[L][0,0])
            print(db)
            y_pred = ff(x_this,W,b)
            diff = 1e-3
            W[1][10,0] = W[1][10,0] + diff
            y_pred_db = ff(x_this,W,b)
            L1 = lossmse(y_this,y_pred)
            L2 = lossmse(y_this,y_pred_db)
            db_finite_difference = (L2-L1)/diff
            print('Original out %f, perturbed out %f' %
                 (y_pred[0,0], y_pred_db[0,0]))
            print('Theoretical dW %f, calculated db %f' %
                  (dW[1][10,0], db_finite_difference[0,0]))
        
        W[L] = W[L] - alpha * dW[L]
        b[L] = b[L] - alpha * db[L]
        
    print('Iteration %d loss %f' % (iter, loss_this_iter))
# Out:
# Iteration 0 loss 138.167398
# Iteration 1 loss 96.131058
# Iteration 2 loss 86.676133
# Iteration 3 loss 81.162155
# Iteration 4 loss 77.945124
# Iteration 5 loss 75.597718
# Iteration 6 loss 73.232075
# Iteration 7 loss 71.920884
# Iteration 8 loss 71.337904
# Iteration 9 loss 70.503157
